# %%
import wfdb
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from scipy.signal import spectrogram

# %% [markdown]
# # Relevant record information
# ### fs: Frequency at which the signals were digitized (in this case 360Hz)
# * time duration = sample count / sampling frequency
# * 360Hz signal, which means 360 samples per second with a total length per record as 650000, or ~30 minutes
# ### sig_len: Signal length (or data points) in the record, where we have 650000 per record
# ### n_sig: How many channels were recorded.
# * channel/Lead: refers to a single electrical signal recording from the heart, representing the voltage difference between two specific electrodes placed on the body (in this case two channels/Leads)
# ### units: Units for each channel (millivolts)
# ### sig_name: The signal name for each channel
# ### comments: Any comments written in the header by cardiologists

# %%
# Path to your data directory
data_dir = '../data/mit-bih-arrhythmia-database-1.0.0'

# List the files in the directory to find one of the ECG files
ecg_file = '100.dat'

# wfdb reads through the .hea and .dat files for record information
# .hea: header file with relevant information about the record (human-readable)
# .dat: binary data file with raw digitized ECG waveforms (machine-readable) 
# sampto: The sample number at which to stop reading for all channels. Reads the entire duration by default.

# Load the ECG data using WFDB
record = wfdb.rdrecord(os.path.join(data_dir, ecg_file.replace('.dat', '')))  # Load the full record

# Inspect basic information about the data
print(f"Record Name: {record.record_name}")
print(f"Number of Signals: {record.p_signal.shape[1]}")  # Use shape to get number of signals
print(f"Sampling Frequency: {record.fs} Hz")
print(f"Signal Shape: {record.p_signal.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 13
#       5 ecg_file = '100.dat'
#       7 # wfdb reads through the .hea and .dat files for record information
#       8 # .hea: header file with relevant information about the record (human-readable)
#       9 # .dat: binary data file with raw digitized ECG waveforms (machine-readable)
#      10 # sampto: The sample number at which to stop reading for all channels. Reads the entire duration by default.
#      11
#      12 # Load the ECG data using WFDB
# ---> 13 record = wfdb.rdrecord(os.path.join(data_dir, ecg_file.replace('.dat', '')))  # Load the full record
#      15 # Inspect basic information about the data
#      16 print(f"Record Name: {record.record_name}")
#
# File ~\anaconda3\Lib\site-packages\wfdb\io\record.py:2029, in rdrecord(record_name, sampfrom, sampto, channels, physical, pn_dir, m2s, smooth_frames, ignore_skew, return_res, force_channels, channel_names, warn_empty)
#    2024     dir_list = pn_dir.split("/")
#    2025     pn_dir = posixpath.join(
#    2026         dir_list[0], download.get_version(dir_list[0]), *dir_list[1:]
#    2027     )
# -> 2029 record = rdheader(record_name, pn_dir=pn_dir, rd_segments=False)
#    2031 # Set defaults for sampto and channels input variables
#    2032 if sampto is None:
#    2033     # If the header does not contain the signal length, figure it
#    2034     # out from the first dat file. This is only possible for single
#    2035     # segment records. If there are no signals, sig_len is 0.
#
# File ~\anaconda3\Lib\site-packages\wfdb\io\record.py:1839, in rdheader(record_name, pn_dir, rd_segments)
#    1837 file_name = f"{base_record_name}.hea"
#    1838 if pn_dir is None:
# -> 1839     with open(
#    1840         os.path.join(dir_name, file_name),
#    1841         "r",
#    1842         encoding="ascii",
#    1843         errors="ignore",
#    1844     ) as f:
#    1845         header_content = f.read()
#    1846 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\julia\\DS4440\\SleepApneaClassifier\\src\\data\\mit-bih-arrhythmia-database-1.0.0\\100.hea'

# %%
# Plot the first 10 seconds of the first ECG signal to get a sense of the data
time = np.arange(0, 10, 1/record.fs)  # Time vector for 10 seconds
plt.plot(time, record.p_signal[:len(time), 0])  # Plot the first signal (ECG)
plt.title(f'ECG Signal from {record.record_name}')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.show()

# %% [markdown]
# Nothing crazy showing here, this seems to be baseline?

# %%
# Path to your data directory
data_dir = '../data/mit-bih-arrhythmia-database-1.0.0'

# Define the ECG file base (e.g., 'a01')
ecg_file_base = '100'

# Load the annotation file (e.g., 'a01.apn')
# wfdb reads through .atr for annotation info and creates an Annotation object
annotation_file = os.path.join(data_dir, f"{ecg_file_base}")
annotations = wfdb.rdann(annotation_file, 'atr')  # Read the apnea annotations

label_count = 0
# Accessing the annotations and printing the relevant details
for i in range(len(annotations.sample)):
    time = annotations.sample[i] / annotations.fs  # Convert sample to time (seconds)
    label = annotations.symbol[i]  # Get the label of the annotation
    print(f"Time: {time:.2f} seconds - Label: {label}")
# Out:
# Time: 0.05 seconds - Label: +
# Time: 0.21 seconds - Label: N
# Time: 1.03 seconds - Label: N
# Time: 1.84 seconds - Label: N
# Time: 2.63 seconds - Label: N
# Time: 3.42 seconds - Label: N
# Time: 4.21 seconds - Label: N
# Time: 5.03 seconds - Label: N
# Time: 5.68 seconds - Label: A
# Time: 6.67 seconds - Label: N
# Time: 7.52 seconds - Label: N
# Time: 8.33 seconds - Label: N
# Time: 9.12 seconds - Label: N
# Time: 9.89 seconds - Label: N
# Time: 10.73 seconds - Label: N
# Time: 11.58 seconds - Label: N
# Time: 12.41 seconds - Label: N
# Time: 13.23 seconds - Label: N
# Time: 14.06 seconds - Label: N
# Time: 14.85 seconds - Label: N
# Time: 15.65 seconds - Label: N
# Time: 16.44 seconds - Label: N
# Time: 17.26 seconds - Label: N
# Time: 18.13 seconds - Label: N
# Time: 18.95 seconds - Label: N
# Time: 19.74 seconds - Label: N
# Time: 20.53 seconds - Label: N
# Time: 21.31 seconds - Label: N
# Time: 22.09 seconds - Label: N
# Time: 22.90 seconds - Label: N
# Time: 23.72 seconds - Label: N
# Time: 24.55 seconds - Label: N
# Time: 25.39 seconds - Label: N
# Time: 26.20 seconds - Label: N
# Time: 26.97 seconds - Label: N
# Time: 27.77 seconds - Label: N
# Time: 28.56 seconds - Label: N
# Time: 29.42 seconds - Label: N
# Time: 30.26 seconds - Label: N
# Time: 31.09 seconds - Label: N
# Time: 31.89 seconds - Label: N
# Time: 32.73 seconds - Label: N
# Time: 33.52 seconds - Label: N
# Time: 34.31 seconds - Label: N
# Time: 35.12 seconds - Label: N
# Time: 35.97 seconds - Label: N
# Time: 36.85 seconds - Label: N
# Time: 37.67 seconds - Label: N
# Time: 38.45 seconds - Label: N
# Time: 39.25 seconds - Label: N
# Time: 40.06 seconds - Label: N
# Time: 40.86 seconds - Label: N
# Time: 41.70 seconds - Label: N
# Time: 42.53 seconds - Label: N
# Time: 43.35 seconds - Label: N
# Time: 44.16 seconds - Label: N
# Time: 44.95 seconds - Label: N
# Time: 45.73 seconds - Label: N
# Time: 46.54 seconds - Label: N
# Time: 47.38 seconds - Label: N
# Time: 48.22 seconds - Label: N
# Time: 49.05 seconds - Label: N
# Time: 49.85 seconds - Label: N
# Time: 50.63 seconds - Label: N
# Time: 51.43 seconds - Label: N
# Time: 52.21 seconds - Label: N
# Time: 53.00 seconds - Label: N
# Time: 53.86 seconds - Label: N
# Time: 54.70 seconds - Label: N
# Time: 55.52 seconds - Label: N
# Time: 56.31 seconds - Label: N
# Time: 57.09 seconds - Label: N
# Time: 57.88 seconds - Label: N
# Time: 58.70 seconds - Label: N
# Time: 59.51 seconds - Label: N
# Time: 60.36 seconds - Label: N
# Time: 61.19 seconds - Label: N
# Time: 62.00 seconds - Label: N
# Time: 62.79 seconds - Label: N
# Time: 63.56 seconds - Label: N
# Time: 64.34 seconds - Label: N
# Time: 65.15 seconds - Label: N
# Time: 65.99 seconds - Label: N
# Time: 66.81 seconds - Label: N
# Time: 67.62 seconds - Label: N
# Time: 68.40 seconds - Label: N
# Time: 69.20 seconds - Label: N
# Time: 69.99 seconds - Label: N
# Time: 70.79 seconds - Label: N
# Time: 71.61 seconds - Label: N
# Time: 72.47 seconds - Label: N
# Time: 73.30 seconds - Label: N
# Time: 74.08 seconds - Label: N
# Time: 74.87 seconds - Label: N
# Time: 75.66 seconds - Label: N
# Time: 76.49 seconds - Label: N
# Time: 77.31 seconds - Label: N
# Time: 78.14 seconds - Label: N
# Time: 78.97 seconds - Label: N
# Time: 79.80 seconds - Label: N
# Time: 80.59 seconds - Label: N
# Time: 81.37 seconds - Label: N
# Time: 82.17 seconds - Label: N
# Time: 82.98 seconds - Label: N
# Time: 83.84 seconds - Label: N
# Time: 84.69 seconds - Label: N
# Time: 85.50 seconds - Label: N
# Time: 86.29 seconds - Label: N
# Time: 87.08 seconds - Label: N
# Time: 87.88 seconds - Label: N
# Time: 88.69 seconds - Label: N
# Time: 89.51 seconds - Label: N
# Time: 90.36 seconds - Label: N
# Time: 91.21 seconds - Label: N
# Time: 92.02 seconds - Label: N
# Time: 92.79 seconds - Label: N
# Time: 93.59 seconds - Label: N
# Time: 94.39 seconds - Label: N
# Time: 95.21 seconds - Label: N
# Time: 96.04 seconds - Label: N
# Time: 96.86 seconds - Label: N
# Time: 97.69 seconds - Label: N
# Time: 98.49 seconds - Label: N
# Time: 99.27 seconds - Label: N
# Time: 100.04 seconds - Label: N
# Time: 100.86 seconds - Label: N
# Time: 101.68 seconds - Label: N
# Time: 102.54 seconds - Label: N
# Time: 103.38 seconds - Label: N
# Time: 104.16 seconds - Label: N
# Time: 104.95 seconds - Label: N
# Time: 105.75 seconds - Label: N
# Time: 106.54 seconds - Label: N
# Time: 107.36 seconds - Label: N
# Time: 108.19 seconds - Label: N
# Time: 109.03 seconds - Label: N
# Time: 109.85 seconds - Label: N
# Time: 110.62 seconds - Label: N
# Time: 111.38 seconds - Label: N
# Time: 112.17 seconds - Label: N
# Time: 112.99 seconds - Label: N
# Time: 113.81 seconds - Label: N
# Time: 114.64 seconds - Label: N
# Time: 115.46 seconds - Label: N
# Time: 116.25 seconds - Label: N
# Time: 116.99 seconds - Label: N
# Time: 117.82 seconds - Label: N
# Time: 118.60 seconds - Label: N
# Time: 119.43 seconds - Label: N
# Time: 120.30 seconds - Label: N
# Time: 121.12 seconds - Label: N
# Time: 121.92 seconds - Label: N
# Time: 122.70 seconds - Label: N
# Time: 123.49 seconds - Label: N
# Time: 124.29 seconds - Label: N
# Time: 125.08 seconds - Label: N
# Time: 125.90 seconds - Label: N
# Time: 126.74 seconds - Label: N
# Time: 127.57 seconds - Label: N
# Time: 128.34 seconds - Label: N
# Time: 129.11 seconds - Label: N
# Time: 129.89 seconds - Label: N
# Time: 130.66 seconds - Label: N
# Time: 131.48 seconds - Label: N
# Time: 132.31 seconds - Label: N
# Time: 133.11 seconds - Label: N
# Time: 133.89 seconds - Label: N
# Time: 134.68 seconds - Label: N
# Time: 135.46 seconds - Label: N
# Time: 136.22 seconds - Label: N
# Time: 137.01 seconds - Label: N
# Time: 137.83 seconds - Label: N
# Time: 138.68 seconds - Label: N
# Time: 139.48 seconds - Label: N
# Time: 140.25 seconds - Label: N
# Time: 141.03 seconds - Label: N
# Time: 141.82 seconds - Label: N
# Time: 142.61 seconds - Label: N
# Time: 143.41 seconds - Label: N
# Time: 144.22 seconds - Label: N
# Time: 145.04 seconds - Label: N
# Time: 145.85 seconds - Label: N
# Time: 146.62 seconds - Label: N
# Time: 147.40 seconds - Label: N
# Time: 148.17 seconds - Label: N
# Time: 148.97 seconds - Label: N
# Time: 149.79 seconds - Label: N
# Time: 150.61 seconds - Label: N
# Time: 151.41 seconds - Label: N
# Time: 152.18 seconds - Label: N
# Time: 152.96 seconds - Label: N
# Time: 153.73 seconds - Label: N
# Time: 154.51 seconds - Label: N
# Time: 155.30 seconds - Label: N
# Time: 156.13 seconds - Label: N
# Time: 156.95 seconds - Label: N
# Time: 157.73 seconds - Label: N
# Time: 158.49 seconds - Label: N
# Time: 159.26 seconds - Label: N
# Time: 160.04 seconds - Label: N
# Time: 160.83 seconds - Label: N
# Time: 161.64 seconds - Label: N
# Time: 162.47 seconds - Label: N
# Time: 163.30 seconds - Label: N
# Time: 164.10 seconds - Label: N
# Time: 164.87 seconds - Label: N
# Time: 165.64 seconds - Label: N
# Time: 166.44 seconds - Label: N
# Time: 167.26 seconds - Label: N
# Time: 168.10 seconds - Label: N
# Time: 168.94 seconds - Label: N
# Time: 169.74 seconds - Label: N
# Time: 170.53 seconds - Label: N
# Time: 171.33 seconds - Label: N
# Time: 172.12 seconds - Label: N
# Time: 172.91 seconds - Label: N
# Time: 173.74 seconds - Label: N
# Time: 174.59 seconds - Label: N
# Time: 175.43 seconds - Label: N
# Time: 176.22 seconds - Label: N
# Time: 176.97 seconds - Label: N
# Time: 177.77 seconds - Label: N
# Time: 178.58 seconds - Label: N
# Time: 179.39 seconds - Label: N
# Time: 180.21 seconds - Label: N
# Time: 181.04 seconds - Label: N
# Time: 181.84 seconds - Label: N
# Time: 182.64 seconds - Label: N
# Time: 183.42 seconds - Label: N
# Time: 184.19 seconds - Label: N
# Time: 185.01 seconds - Label: N
# Time: 185.53 seconds - Label: A
# Time: 186.47 seconds - Label: N
# Time: 187.32 seconds - Label: N
# Time: 188.13 seconds - Label: N
# Time: 188.91 seconds - Label: N
# Time: 189.73 seconds - Label: N
# Time: 190.54 seconds - Label: N
# Time: 191.35 seconds - Label: N
# Time: 192.20 seconds - Label: N
# Time: 193.06 seconds - Label: N
# Time: 193.88 seconds - Label: N
# Time: 194.65 seconds - Label: N
# Time: 195.44 seconds - Label: N
# Time: 196.23 seconds - Label: N
# Time: 197.06 seconds - Label: N
# Time: 197.89 seconds - Label: N
# Time: 198.72 seconds - Label: N
# Time: 199.57 seconds - Label: N
# Time: 200.38 seconds - Label: N
# Time: 201.16 seconds - Label: N
# Time: 201.95 seconds - Label: N
# Time: 202.77 seconds - Label: N
# Time: 203.61 seconds - Label: N
# Time: 204.47 seconds - Label: N
# Time: 205.31 seconds - Label: N
# Time: 206.10 seconds - Label: N
# Time: 206.90 seconds - Label: N
# Time: 207.69 seconds - Label: N
# Time: 208.29 seconds - Label: A
# Time: 209.26 seconds - Label: N
# Time: 210.09 seconds - Label: N
# Time: 210.93 seconds - Label: N
# Time: 211.76 seconds - Label: N
# Time: 212.54 seconds - Label: N
# Time: 213.29 seconds - Label: N
# Time: 214.09 seconds - Label: N
# Time: 214.91 seconds - Label: N
# Time: 215.73 seconds - Label: N
# Time: 216.54 seconds - Label: N
# Time: 217.36 seconds - Label: N
# Time: 218.16 seconds - Label: N
# Time: 218.96 seconds - Label: N
# Time: 219.72 seconds - Label: N
# Time: 220.52 seconds - Label: N
# Time: 221.36 seconds - Label: N
# Time: 222.20 seconds - Label: N
# Time: 223.03 seconds - Label: N
# Time: 223.84 seconds - Label: N
# Time: 224.63 seconds - Label: N
# Time: 225.42 seconds - Label: N
# Time: 226.22 seconds - Label: N
# Time: 227.03 seconds - Label: N
# Time: 227.86 seconds - Label: N
# Time: 228.71 seconds - Label: N
# Time: 229.54 seconds - Label: N
# Time: 230.35 seconds - Label: N
# Time: 231.14 seconds - Label: N
# Time: 231.92 seconds - Label: N
# Time: 232.76 seconds - Label: N
# Time: 233.62 seconds - Label: N
# Time: 234.46 seconds - Label: N
# Time: 235.30 seconds - Label: N
# Time: 236.14 seconds - Label: N
# Time: 236.95 seconds - Label: N
# Time: 237.72 seconds - Label: N
# Time: 238.53 seconds - Label: N
# Time: 239.36 seconds - Label: N
# Time: 240.22 seconds - Label: N
# Time: 241.06 seconds - Label: N
# Time: 241.89 seconds - Label: N
# Time: 242.68 seconds - Label: N
# Time: 243.48 seconds - Label: N
# Time: 244.28 seconds - Label: N
# Time: 245.09 seconds - Label: N
# Time: 245.92 seconds - Label: N
# Time: 246.76 seconds - Label: N
# Time: 247.60 seconds - Label: N
# Time: 248.39 seconds - Label: N
# Time: 249.18 seconds - Label: N
# Time: 249.97 seconds - Label: N
# Time: 250.79 seconds - Label: N
# Time: 251.64 seconds - Label: N
# Time: 252.46 seconds - Label: N
# Time: 253.31 seconds - Label: N
# Time: 254.11 seconds - Label: N
# Time: 254.89 seconds - Label: N
# Time: 255.68 seconds - Label: N
# Time: 256.49 seconds - Label: N
# Time: 257.31 seconds - Label: N
# Time: 258.18 seconds - Label: N
# Time: 259.02 seconds - Label: N
# Time: 259.82 seconds - Label: N
# Time: 260.62 seconds - Label: N
# Time: 261.39 seconds - Label: N
# Time: 262.21 seconds - Label: N
# Time: 263.04 seconds - Label: N
# Time: 263.88 seconds - Label: N
# Time: 264.72 seconds - Label: N
# Time: 265.57 seconds - Label: N
# Time: 266.37 seconds - Label: N
# Time: 267.14 seconds - Label: N
# Time: 267.92 seconds - Label: N
# Time: 268.74 seconds - Label: N
# Time: 269.58 seconds - Label: N
# Time: 270.41 seconds - Label: N
# Time: 271.23 seconds - Label: N
# Time: 272.04 seconds - Label: N
# Time: 272.86 seconds - Label: N
# Time: 273.63 seconds - Label: N
# Time: 274.41 seconds - Label: N
# Time: 275.23 seconds - Label: N
# Time: 276.06 seconds - Label: N
# Time: 276.61 seconds - Label: A
# Time: 277.58 seconds - Label: N
# Time: 278.38 seconds - Label: N
# Time: 279.16 seconds - Label: N
# Time: 279.95 seconds - Label: N
# Time: 280.75 seconds - Label: N
# Time: 281.56 seconds - Label: N
# Time: 282.37 seconds - Label: N
# Time: 283.17 seconds - Label: N
# Time: 283.98 seconds - Label: N
# Time: 284.77 seconds - Label: N
# Time: 285.54 seconds - Label: N
# Time: 286.32 seconds - Label: N
# Time: 287.14 seconds - Label: N
# Time: 287.97 seconds - Label: N
# Time: 288.79 seconds - Label: N
# Time: 289.61 seconds - Label: N
# Time: 290.40 seconds - Label: N
# Time: 291.19 seconds - Label: N
# Time: 291.99 seconds - Label: N
# Time: 292.80 seconds - Label: N
# Time: 293.63 seconds - Label: N
# Time: 294.49 seconds - Label: N
# Time: 295.32 seconds - Label: N
# Time: 296.11 seconds - Label: N
# Time: 296.89 seconds - Label: N
# Time: 297.66 seconds - Label: N
# Time: 298.48 seconds - Label: N
# Time: 299.31 seconds - Label: N
# Time: 300.12 seconds - Label: N
# Time: 300.95 seconds - Label: N
# Time: 301.79 seconds - Label: N
# Time: 302.57 seconds - Label: N
# Time: 303.33 seconds - Label: N
# Time: 304.13 seconds - Label: N
# Time: 304.92 seconds - Label: N
# Time: 305.77 seconds - Label: N
# Time: 306.59 seconds - Label: N
# Time: 307.43 seconds - Label: N
# Time: 308.23 seconds - Label: N
# Time: 309.01 seconds - Label: N
# Time: 309.79 seconds - Label: N
# Time: 310.58 seconds - Label: N
# Time: 311.41 seconds - Label: N
# Time: 312.24 seconds - Label: N
# Time: 313.08 seconds - Label: N
# Time: 313.89 seconds - Label: N
# Time: 314.67 seconds - Label: N
# Time: 315.45 seconds - Label: N
# Time: 316.25 seconds - Label: N
# Time: 317.06 seconds - Label: N
# Time: 317.86 seconds - Label: N
# Time: 318.66 seconds - Label: N
# Time: 319.44 seconds - Label: N
# Time: 320.22 seconds - Label: N
# Time: 320.96 seconds - Label: N
# Time: 321.71 seconds - Label: N
# Time: 322.46 seconds - Label: N
# Time: 323.25 seconds - Label: N
# Time: 324.04 seconds - Label: N
# Time: 324.83 seconds - Label: N
# Time: 325.59 seconds - Label: N
# Time: 326.37 seconds - Label: N
# Time: 327.13 seconds - Label: N
# Time: 327.90 seconds - Label: N
# Time: 328.68 seconds - Label: N
# Time: 329.46 seconds - Label: N
# Time: 330.31 seconds - Label: N
# Time: 331.15 seconds - Label: N
# Time: 331.97 seconds - Label: N
# Time: 332.75 seconds - Label: N
# Time: 333.55 seconds - Label: N
# Time: 334.38 seconds - Label: N
# Time: 335.21 seconds - Label: N
# Time: 336.08 seconds - Label: N
# Time: 336.94 seconds - Label: N
# Time: 337.79 seconds - Label: N
# Time: 338.58 seconds - Label: N
# Time: 339.36 seconds - Label: N
# Time: 340.17 seconds - Label: N
# Time: 340.97 seconds - Label: N
# Time: 341.81 seconds - Label: N
# Time: 342.67 seconds - Label: N
# Time: 343.51 seconds - Label: N
# Time: 344.27 seconds - Label: N
# Time: 345.06 seconds - Label: N
# Time: 345.85 seconds - Label: N
# Time: 346.60 seconds - Label: N
# Time: 347.39 seconds - Label: N
# Time: 348.21 seconds - Label: N
# Time: 349.02 seconds - Label: N
# Time: 349.79 seconds - Label: N
# Time: 350.56 seconds - Label: N
# Time: 351.32 seconds - Label: N
# Time: 352.07 seconds - Label: N
# Time: 352.85 seconds - Label: N
# Time: 353.65 seconds - Label: N
# Time: 354.45 seconds - Label: N
# Time: 355.26 seconds - Label: N
# Time: 355.79 seconds - Label: A
# Time: 356.73 seconds - Label: N
# Time: 357.49 seconds - Label: N
# Time: 358.22 seconds - Label: N
# Time: 358.97 seconds - Label: N
# Time: 359.77 seconds - Label: N
# Time: 360.55 seconds - Label: N
# Time: 361.27 seconds - Label: N
# Time: 361.99 seconds - Label: N
# Time: 362.69 seconds - Label: N
# Time: 363.38 seconds - Label: N
# Time: 364.09 seconds - Label: N
# Time: 364.79 seconds - Label: N
# Time: 365.51 seconds - Label: N
# Time: 366.25 seconds - Label: N
# Time: 367.01 seconds - Label: N
# Time: 367.73 seconds - Label: N
# Time: 368.41 seconds - Label: N
# Time: 369.12 seconds - Label: N
# Time: 369.81 seconds - Label: N
# Time: 370.53 seconds - Label: N
# Time: 371.28 seconds - Label: N
# Time: 372.04 seconds - Label: N
# Time: 372.77 seconds - Label: N
# Time: 373.51 seconds - Label: N
# Time: 374.27 seconds - Label: N
# Time: 374.97 seconds - Label: N
# Time: 375.68 seconds - Label: N
# Time: 376.40 seconds - Label: N
# Time: 377.17 seconds - Label: N
# Time: 377.95 seconds - Label: N
# Time: 378.75 seconds - Label: N
# Time: 379.53 seconds - Label: N
# Time: 380.27 seconds - Label: N
# Time: 381.03 seconds - Label: N
# Time: 381.80 seconds - Label: N
# Time: 382.58 seconds - Label: N
# Time: 383.36 seconds - Label: N
# Time: 384.18 seconds - Label: N
# Time: 384.99 seconds - Label: N
# Time: 385.80 seconds - Label: N
# Time: 386.57 seconds - Label: N
# Time: 387.33 seconds - Label: N
# Time: 388.11 seconds - Label: N
# Time: 388.91 seconds - Label: N
# Time: 389.73 seconds - Label: N
# Time: 390.55 seconds - Label: N
# Time: 391.34 seconds - Label: N
# Time: 392.09 seconds - Label: N
# Time: 392.84 seconds - Label: N
# Time: 393.57 seconds - Label: N
# Time: 394.29 seconds - Label: N
# Time: 395.02 seconds - Label: N
# Time: 395.77 seconds - Label: N
# Time: 396.52 seconds - Label: N
# Time: 397.25 seconds - Label: N
# Time: 397.96 seconds - Label: N
# Time: 398.65 seconds - Label: N
# Time: 399.35 seconds - Label: N
# Time: 400.07 seconds - Label: N
# Time: 400.79 seconds - Label: N
# Time: 401.55 seconds - Label: N
# Time: 402.31 seconds - Label: N
# Time: 403.09 seconds - Label: N
# Time: 403.84 seconds - Label: N
# Time: 404.57 seconds - Label: N
# Time: 405.28 seconds - Label: N
# Time: 406.03 seconds - Label: N
# Time: 406.79 seconds - Label: N
# Time: 407.60 seconds - Label: N
# Time: 408.37 seconds - Label: N
# Time: 409.14 seconds - Label: N
# Time: 409.90 seconds - Label: N
# Time: 410.64 seconds - Label: N
# Time: 411.39 seconds - Label: N
# Time: 412.12 seconds - Label: N
# Time: 412.88 seconds - Label: N
# Time: 413.66 seconds - Label: N
# Time: 414.46 seconds - Label: N
# Time: 415.24 seconds - Label: N
# Time: 416.02 seconds - Label: N
# Time: 416.75 seconds - Label: N
# Time: 417.51 seconds - Label: N
# Time: 418.26 seconds - Label: N
# Time: 419.02 seconds - Label: N
# Time: 419.78 seconds - Label: N
# Time: 420.57 seconds - Label: N
# Time: 421.39 seconds - Label: N
# Time: 422.15 seconds - Label: N
# Time: 422.88 seconds - Label: N
# Time: 423.64 seconds - Label: N
# Time: 424.39 seconds - Label: N
# Time: 425.19 seconds - Label: N
# Time: 426.01 seconds - Label: N
# Time: 426.79 seconds - Label: N
# Time: 427.56 seconds - Label: N
# Time: 428.31 seconds - Label: N
# Time: 429.08 seconds - Label: N
# Time: 429.84 seconds - Label: N
# Time: 430.58 seconds - Label: N
# Time: 431.36 seconds - Label: N
# Time: 432.19 seconds - Label: N
# Time: 432.96 seconds - Label: N
# Time: 433.70 seconds - Label: N
# Time: 434.43 seconds - Label: N
# Time: 435.13 seconds - Label: N
# Time: 435.85 seconds - Label: N
# Time: 436.58 seconds - Label: N
# Time: 437.31 seconds - Label: N
# Time: 438.04 seconds - Label: N
# Time: 438.78 seconds - Label: N
# Time: 439.54 seconds - Label: N
# Time: 440.25 seconds - Label: N
# Time: 440.92 seconds - Label: N
# Time: 441.59 seconds - Label: N
# Time: 442.29 seconds - Label: N
# Time: 443.00 seconds - Label: N
# Time: 443.72 seconds - Label: N
# Time: 444.45 seconds - Label: N
# Time: 445.17 seconds - Label: N
# Time: 445.85 seconds - Label: N
# Time: 446.54 seconds - Label: N
# Time: 447.24 seconds - Label: N
# Time: 447.93 seconds - Label: N
# Time: 448.61 seconds - Label: N
# Time: 449.34 seconds - Label: N
# Time: 450.10 seconds - Label: N
# Time: 450.86 seconds - Label: N
# Time: 451.59 seconds - Label: N
# Time: 452.32 seconds - Label: N
# Time: 453.04 seconds - Label: N
# Time: 453.78 seconds - Label: N
# Time: 454.52 seconds - Label: N
# Time: 455.27 seconds - Label: N
# Time: 456.06 seconds - Label: N
# Time: 456.84 seconds - Label: N
# Time: 457.59 seconds - Label: N
# Time: 458.31 seconds - Label: N
# Time: 459.02 seconds - Label: N
# Time: 459.72 seconds - Label: N
# Time: 460.43 seconds - Label: N
# Time: 461.20 seconds - Label: N
# Time: 461.95 seconds - Label: N
# Time: 462.69 seconds - Label: N
# Time: 463.45 seconds - Label: N
# Time: 464.20 seconds - Label: N
# Time: 464.92 seconds - Label: N
# Time: 465.67 seconds - Label: N
# Time: 466.42 seconds - Label: N
# Time: 467.20 seconds - Label: N
# Time: 468.01 seconds - Label: N
# Time: 468.84 seconds - Label: N
# Time: 469.65 seconds - Label: N
# Time: 470.41 seconds - Label: N
# Time: 471.19 seconds - Label: N
# Time: 471.96 seconds - Label: N
# Time: 472.78 seconds - Label: N
# Time: 473.60 seconds - Label: N
# Time: 474.22 seconds - Label: A
# Time: 475.21 seconds - Label: N
# Time: 476.03 seconds - Label: N
# Time: 476.81 seconds - Label: N
# Time: 477.56 seconds - Label: N
# Time: 478.33 seconds - Label: N
# Time: 479.11 seconds - Label: N
# Time: 479.93 seconds - Label: N
# Time: 480.74 seconds - Label: N
# Time: 481.53 seconds - Label: N
# Time: 482.30 seconds - Label: N
# Time: 483.07 seconds - Label: N
# Time: 483.82 seconds - Label: N
# Time: 484.59 seconds - Label: N
# Time: 485.38 seconds - Label: N
# Time: 486.18 seconds - Label: N
# Time: 487.01 seconds - Label: N
# Time: 487.80 seconds - Label: N
# Time: 488.55 seconds - Label: N
# Time: 489.29 seconds - Label: N
# Time: 490.07 seconds - Label: N
# Time: 490.83 seconds - Label: N
# Time: 491.60 seconds - Label: N
# Time: 492.36 seconds - Label: N
# Time: 493.12 seconds - Label: N
# Time: 493.88 seconds - Label: N
# Time: 494.61 seconds - Label: N
# Time: 495.32 seconds - Label: N
# Time: 496.05 seconds - Label: N
# Time: 496.78 seconds - Label: N
# Time: 497.55 seconds - Label: N
# Time: 498.30 seconds - Label: N
# Time: 499.06 seconds - Label: N
# Time: 499.80 seconds - Label: N
# Time: 500.51 seconds - Label: N
# Time: 501.23 seconds - Label: N
# Time: 501.96 seconds - Label: N
# Time: 502.68 seconds - Label: N
# Time: 503.43 seconds - Label: N
# Time: 504.23 seconds - Label: N
# Time: 505.03 seconds - Label: N
# Time: 505.79 seconds - Label: N
# Time: 506.54 seconds - Label: N
# Time: 507.29 seconds - Label: N
# Time: 508.04 seconds - Label: N
# Time: 508.84 seconds - Label: N
# Time: 509.65 seconds - Label: N
# Time: 510.49 seconds - Label: N
# Time: 511.31 seconds - Label: N
# Time: 512.11 seconds - Label: N
# Time: 512.91 seconds - Label: N
# Time: 513.70 seconds - Label: N
# Time: 514.48 seconds - Label: N
# Time: 515.31 seconds - Label: N
# Time: 516.19 seconds - Label: N
# Time: 517.05 seconds - Label: N
# Time: 517.86 seconds - Label: N
# Time: 518.66 seconds - Label: N
# Time: 519.46 seconds - Label: N
# Time: 520.25 seconds - Label: N
# Time: 521.05 seconds - Label: N
# Time: 521.87 seconds - Label: N
# Time: 522.72 seconds - Label: N
# Time: 523.56 seconds - Label: N
# Time: 524.34 seconds - Label: N
# Time: 525.12 seconds - Label: N
# Time: 525.92 seconds - Label: N
# Time: 526.73 seconds - Label: N
# Time: 527.58 seconds - Label: N
# Time: 528.41 seconds - Label: N
# Time: 529.25 seconds - Label: N
# Time: 530.06 seconds - Label: N
# Time: 530.87 seconds - Label: N
# Time: 531.65 seconds - Label: N
# Time: 532.43 seconds - Label: N
# Time: 533.27 seconds - Label: N
# Time: 534.11 seconds - Label: N
# Time: 534.93 seconds - Label: N
# Time: 535.73 seconds - Label: N
# Time: 536.52 seconds - Label: N
# Time: 537.29 seconds - Label: N
# Time: 538.06 seconds - Label: N
# Time: 538.87 seconds - Label: N
# Time: 539.67 seconds - Label: N
# Time: 540.48 seconds - Label: N
# Time: 541.30 seconds - Label: N
# Time: 542.10 seconds - Label: N
# Time: 542.85 seconds - Label: N
# Time: 543.61 seconds - Label: N
# Time: 544.38 seconds - Label: N
# Time: 545.19 seconds - Label: N
# Time: 546.00 seconds - Label: N
# Time: 546.80 seconds - Label: N
# Time: 547.59 seconds - Label: N
# Time: 548.37 seconds - Label: N
# Time: 549.12 seconds - Label: N
# Time: 549.86 seconds - Label: N
# Time: 550.62 seconds - Label: N
# Time: 551.40 seconds - Label: N
# Time: 552.20 seconds - Label: N
# Time: 552.99 seconds - Label: N
# Time: 553.76 seconds - Label: N
# Time: 554.50 seconds - Label: N
# Time: 555.26 seconds - Label: N
# Time: 556.00 seconds - Label: N
# Time: 556.76 seconds - Label: N
# Time: 557.54 seconds - Label: N
# Time: 558.31 seconds - Label: N
# Time: 559.09 seconds - Label: N
# Time: 559.85 seconds - Label: N
# Time: 560.57 seconds - Label: N
# Time: 561.30 seconds - Label: N
# Time: 562.05 seconds - Label: N
# Time: 562.82 seconds - Label: N
# Time: 563.60 seconds - Label: N
# Time: 564.39 seconds - Label: N
# Time: 565.19 seconds - Label: N
# Time: 565.95 seconds - Label: N
# Time: 566.73 seconds - Label: N
# Time: 567.50 seconds - Label: N
# Time: 568.26 seconds - Label: N
# Time: 569.04 seconds - Label: N
# Time: 569.88 seconds - Label: N
# Time: 570.72 seconds - Label: N
# Time: 571.49 seconds - Label: N
# Time: 572.27 seconds - Label: N
# Time: 573.02 seconds - Label: N
# Time: 573.80 seconds - Label: N
# Time: 574.57 seconds - Label: N
# Time: 575.36 seconds - Label: N
# Time: 576.17 seconds - Label: N
# Time: 577.01 seconds - Label: N
# Time: 577.79 seconds - Label: N
# Time: 578.55 seconds - Label: N
# Time: 579.30 seconds - Label: N
# Time: 580.06 seconds - Label: N
# Time: 580.83 seconds - Label: N
# Time: 581.64 seconds - Label: N
# Time: 582.45 seconds - Label: N
# Time: 583.26 seconds - Label: N
# Time: 584.04 seconds - Label: N
# Time: 584.82 seconds - Label: N
# Time: 585.58 seconds - Label: N
# Time: 586.35 seconds - Label: N
# Time: 587.12 seconds - Label: N
# Time: 587.93 seconds - Label: N
# Time: 588.75 seconds - Label: N
# Time: 589.52 seconds - Label: N
# Time: 590.28 seconds - Label: N
# Time: 591.05 seconds - Label: N
# Time: 591.83 seconds - Label: N
# Time: 592.57 seconds - Label: N
# Time: 593.35 seconds - Label: N
# Time: 594.15 seconds - Label: N
# Time: 594.95 seconds - Label: N
# Time: 595.74 seconds - Label: N
# Time: 596.49 seconds - Label: N
# Time: 597.24 seconds - Label: N
# Time: 598.00 seconds - Label: N
# Time: 598.79 seconds - Label: N
# Time: 599.58 seconds - Label: N
# Time: 600.39 seconds - Label: N
# Time: 601.20 seconds - Label: N
# Time: 601.97 seconds - Label: N
# Time: 602.75 seconds - Label: N
# Time: 603.52 seconds - Label: N
# Time: 604.30 seconds - Label: N
# Time: 605.07 seconds - Label: N
# Time: 605.89 seconds - Label: N
# Time: 606.71 seconds - Label: N
# Time: 607.51 seconds - Label: N
# Time: 608.26 seconds - Label: N
# Time: 609.02 seconds - Label: N
# Time: 609.80 seconds - Label: N
# Time: 610.59 seconds - Label: N
# Time: 611.38 seconds - Label: N
# Time: 612.20 seconds - Label: N
# Time: 613.03 seconds - Label: N
# Time: 613.83 seconds - Label: N
# Time: 614.59 seconds - Label: N
# Time: 615.35 seconds - Label: N
# Time: 616.12 seconds - Label: N
# Time: 616.89 seconds - Label: N
# Time: 617.71 seconds - Label: N
# Time: 618.52 seconds - Label: N
# Time: 619.31 seconds - Label: N
# Time: 620.08 seconds - Label: N
# Time: 620.85 seconds - Label: N
# Time: 621.62 seconds - Label: N
# Time: 622.35 seconds - Label: N
# Time: 623.13 seconds - Label: N
# Time: 623.95 seconds - Label: N
# Time: 624.76 seconds - Label: N
# Time: 625.54 seconds - Label: N
# Time: 626.31 seconds - Label: N
# Time: 627.06 seconds - Label: N
# Time: 627.84 seconds - Label: N
# Time: 628.60 seconds - Label: N
# Time: 629.37 seconds - Label: N
# Time: 630.17 seconds - Label: N
# Time: 630.96 seconds - Label: N
# Time: 631.74 seconds - Label: N
# Time: 632.51 seconds - Label: N
# Time: 633.26 seconds - Label: N
# Time: 633.99 seconds - Label: N
# Time: 634.77 seconds - Label: N
# Time: 635.58 seconds - Label: N
# Time: 636.37 seconds - Label: N
# Time: 637.16 seconds - Label: N
# Time: 637.94 seconds - Label: N
# Time: 638.71 seconds - Label: N
# Time: 639.48 seconds - Label: N
# Time: 640.24 seconds - Label: N
# Time: 641.00 seconds - Label: N
# Time: 641.83 seconds - Label: N
# Time: 642.66 seconds - Label: N
# Time: 643.44 seconds - Label: N
# Time: 644.20 seconds - Label: N
# Time: 644.97 seconds - Label: N
# Time: 645.72 seconds - Label: N
# Time: 646.48 seconds - Label: N
# Time: 647.27 seconds - Label: N
# Time: 648.06 seconds - Label: N
# Time: 648.86 seconds - Label: N
# Time: 649.65 seconds - Label: N
# Time: 650.42 seconds - Label: N
# Time: 651.15 seconds - Label: N
# Time: 651.90 seconds - Label: N
# Time: 652.66 seconds - Label: N
# Time: 653.47 seconds - Label: N
# Time: 654.30 seconds - Label: N
# Time: 655.08 seconds - Label: N
# Time: 655.86 seconds - Label: N
# Time: 656.64 seconds - Label: N
# Time: 657.40 seconds - Label: N
# Time: 658.13 seconds - Label: N
# Time: 658.90 seconds - Label: N
# Time: 659.71 seconds - Label: N
# Time: 660.51 seconds - Label: N
# Time: 661.31 seconds - Label: N
# Time: 662.06 seconds - Label: N
# Time: 662.81 seconds - Label: N
# Time: 663.57 seconds - Label: N
# Time: 664.33 seconds - Label: N
# Time: 665.09 seconds - Label: N
# Time: 665.88 seconds - Label: N
# Time: 666.66 seconds - Label: N
# Time: 667.41 seconds - Label: N
# Time: 668.17 seconds - Label: N
# Time: 668.91 seconds - Label: N
# Time: 669.62 seconds - Label: N
# Time: 670.33 seconds - Label: N
# Time: 671.08 seconds - Label: N
# Time: 671.82 seconds - Label: N
# Time: 672.54 seconds - Label: N
# Time: 673.26 seconds - Label: N
# Time: 673.98 seconds - Label: N
# Time: 674.66 seconds - Label: N
# Time: 675.37 seconds - Label: N
# Time: 676.08 seconds - Label: N
# Time: 676.79 seconds - Label: N
# Time: 677.52 seconds - Label: N
# Time: 678.31 seconds - Label: N
# Time: 679.06 seconds - Label: N
# Time: 679.80 seconds - Label: N
# Time: 680.51 seconds - Label: N
# Time: 681.24 seconds - Label: N
# Time: 681.99 seconds - Label: N
# Time: 682.75 seconds - Label: N
# Time: 683.51 seconds - Label: N
# Time: 684.31 seconds - Label: N
# Time: 685.13 seconds - Label: N
# Time: 685.93 seconds - Label: N
# Time: 686.67 seconds - Label: N
# Time: 687.41 seconds - Label: N
# Time: 688.17 seconds - Label: N
# Time: 688.94 seconds - Label: N
# Time: 689.72 seconds - Label: N
# Time: 690.52 seconds - Label: N
# Time: 691.33 seconds - Label: N
# Time: 692.11 seconds - Label: N
# Time: 692.87 seconds - Label: N
# Time: 693.63 seconds - Label: N
# Time: 694.41 seconds - Label: N
# Time: 695.20 seconds - Label: N
# Time: 695.99 seconds - Label: N
# Time: 696.83 seconds - Label: N
# Time: 697.67 seconds - Label: N
# Time: 698.45 seconds - Label: N
# Time: 699.19 seconds - Label: N
# Time: 699.98 seconds - Label: N
# Time: 700.79 seconds - Label: N
# Time: 701.62 seconds - Label: N
# Time: 702.41 seconds - Label: N
# Time: 703.22 seconds - Label: N
# Time: 704.04 seconds - Label: N
# Time: 704.84 seconds - Label: N
# Time: 705.58 seconds - Label: N
# Time: 706.34 seconds - Label: N
# Time: 707.18 seconds - Label: N
# Time: 708.03 seconds - Label: N
# Time: 708.81 seconds - Label: N
# Time: 709.59 seconds - Label: N
# Time: 710.38 seconds - Label: N
# Time: 711.19 seconds - Label: N
# Time: 711.93 seconds - Label: N
# Time: 712.70 seconds - Label: N
# Time: 713.50 seconds - Label: N
# Time: 714.33 seconds - Label: N
# Time: 715.11 seconds - Label: N
# Time: 715.86 seconds - Label: N
# Time: 716.57 seconds - Label: N
# Time: 717.29 seconds - Label: N
# Time: 717.99 seconds - Label: N
# Time: 718.71 seconds - Label: N
# Time: 719.46 seconds - Label: N
# Time: 720.22 seconds - Label: N
# Time: 720.95 seconds - Label: N
# Time: 721.70 seconds - Label: N
# Time: 722.43 seconds - Label: N
# Time: 723.15 seconds - Label: N
# Time: 723.85 seconds - Label: N
# Time: 724.59 seconds - Label: N
# Time: 725.37 seconds - Label: N
# Time: 726.16 seconds - Label: N
# Time: 726.92 seconds - Label: N
# Time: 727.69 seconds - Label: N
# Time: 728.45 seconds - Label: N
# Time: 729.21 seconds - Label: N
# Time: 729.97 seconds - Label: N
# Time: 730.73 seconds - Label: N
# Time: 731.53 seconds - Label: N
# Time: 732.34 seconds - Label: N
# Time: 733.14 seconds - Label: N
# Time: 733.94 seconds - Label: N
# Time: 734.72 seconds - Label: N
# Time: 735.48 seconds - Label: N
# Time: 736.28 seconds - Label: N
# Time: 737.09 seconds - Label: N
# Time: 737.92 seconds - Label: N
# Time: 738.74 seconds - Label: N
# Time: 739.55 seconds - Label: N
# Time: 740.36 seconds - Label: N
# Time: 741.15 seconds - Label: N
# Time: 741.94 seconds - Label: N
# Time: 742.71 seconds - Label: N
# Time: 743.55 seconds - Label: N
# Time: 744.38 seconds - Label: N
# Time: 745.17 seconds - Label: N
# Time: 745.96 seconds - Label: N
# Time: 746.73 seconds - Label: N
# Time: 747.51 seconds - Label: N
# Time: 748.29 seconds - Label: N
# Time: 749.08 seconds - Label: N
# Time: 749.89 seconds - Label: N
# Time: 750.71 seconds - Label: N
# Time: 751.53 seconds - Label: N
# Time: 752.28 seconds - Label: N
# Time: 753.04 seconds - Label: N
# Time: 753.81 seconds - Label: N
# Time: 754.60 seconds - Label: N
# Time: 755.42 seconds - Label: N
# Time: 756.23 seconds - Label: N
# Time: 757.04 seconds - Label: N
# Time: 757.89 seconds - Label: N
# Time: 758.67 seconds - Label: N
# Time: 759.43 seconds - Label: N
# Time: 760.21 seconds - Label: N
# Time: 761.02 seconds - Label: N
# Time: 761.84 seconds - Label: N
# Time: 762.67 seconds - Label: N
# Time: 763.48 seconds - Label: N
# Time: 764.25 seconds - Label: N
# Time: 765.01 seconds - Label: N
# Time: 765.75 seconds - Label: N
# Time: 766.52 seconds - Label: N
# Time: 767.32 seconds - Label: N
# Time: 768.10 seconds - Label: N
# Time: 768.90 seconds - Label: N
# Time: 769.73 seconds - Label: N
# Time: 770.52 seconds - Label: N
# Time: 771.25 seconds - Label: N
# Time: 772.01 seconds - Label: N
# Time: 772.81 seconds - Label: N
# Time: 773.66 seconds - Label: N
# Time: 774.48 seconds - Label: N
# Time: 775.27 seconds - Label: N
# Time: 776.06 seconds - Label: N
# Time: 776.60 seconds - Label: A
# Time: 777.55 seconds - Label: N
# Time: 778.36 seconds - Label: N
# Time: 779.20 seconds - Label: N
# Time: 780.04 seconds - Label: N
# Time: 780.86 seconds - Label: N
# Time: 781.67 seconds - Label: N
# Time: 782.45 seconds - Label: N
# Time: 783.21 seconds - Label: N
# Time: 783.98 seconds - Label: N
# Time: 784.76 seconds - Label: N
# Time: 785.56 seconds - Label: N
# Time: 786.38 seconds - Label: N
# Time: 787.19 seconds - Label: N
# Time: 787.98 seconds - Label: N
# Time: 788.73 seconds - Label: N
# Time: 789.49 seconds - Label: N
# Time: 790.25 seconds - Label: N
# Time: 791.05 seconds - Label: N
# Time: 791.87 seconds - Label: N
# Time: 792.67 seconds - Label: N
# Time: 793.48 seconds - Label: N
# Time: 794.27 seconds - Label: N
# Time: 795.03 seconds - Label: N
# Time: 795.79 seconds - Label: N
# Time: 796.56 seconds - Label: N
# Time: 797.36 seconds - Label: N
# Time: 798.20 seconds - Label: N
# Time: 799.04 seconds - Label: N
# Time: 799.84 seconds - Label: N
# Time: 800.62 seconds - Label: N
# Time: 801.41 seconds - Label: N
# Time: 802.20 seconds - Label: N
# Time: 802.99 seconds - Label: N
# Time: 803.81 seconds - Label: N
# Time: 804.63 seconds - Label: N
# Time: 805.48 seconds - Label: N
# Time: 806.27 seconds - Label: N
# Time: 807.05 seconds - Label: N
# Time: 807.81 seconds - Label: N
# Time: 808.64 seconds - Label: N
# Time: 809.46 seconds - Label: N
# Time: 810.27 seconds - Label: N
# Time: 811.08 seconds - Label: N
# Time: 811.89 seconds - Label: N
# Time: 812.68 seconds - Label: N
# Time: 813.46 seconds - Label: N
# Time: 814.23 seconds - Label: N
# Time: 815.03 seconds - Label: N
# Time: 815.87 seconds - Label: N
# Time: 816.70 seconds - Label: N
# Time: 817.49 seconds - Label: N
# Time: 818.28 seconds - Label: N
# Time: 819.05 seconds - Label: N
# Time: 819.84 seconds - Label: N
# Time: 820.61 seconds - Label: N
# Time: 821.44 seconds - Label: N
# Time: 822.26 seconds - Label: N
# Time: 823.11 seconds - Label: N
# Time: 823.92 seconds - Label: N
# Time: 824.69 seconds - Label: N
# Time: 825.47 seconds - Label: N
# Time: 826.25 seconds - Label: N
# Time: 827.05 seconds - Label: N
# Time: 827.87 seconds - Label: N
# Time: 828.71 seconds - Label: N
# Time: 829.52 seconds - Label: N
# Time: 830.33 seconds - Label: N
# Time: 831.13 seconds - Label: N
# Time: 831.90 seconds - Label: N
# Time: 832.66 seconds - Label: N
# Time: 833.48 seconds - Label: N
# Time: 834.33 seconds - Label: N
# Time: 835.17 seconds - Label: N
# Time: 835.94 seconds - Label: N
# Time: 836.69 seconds - Label: N
# Time: 837.48 seconds - Label: N
# Time: 838.28 seconds - Label: N
# Time: 839.06 seconds - Label: N
# Time: 839.85 seconds - Label: N
# Time: 840.68 seconds - Label: N
# Time: 841.52 seconds - Label: N
# Time: 842.33 seconds - Label: N
# Time: 843.06 seconds - Label: N
# Time: 843.81 seconds - Label: N
# Time: 844.62 seconds - Label: N
# Time: 845.45 seconds - Label: N
# Time: 846.22 seconds - Label: N
# Time: 847.01 seconds - Label: N
# Time: 847.81 seconds - Label: N
# Time: 848.60 seconds - Label: N
# Time: 849.19 seconds - Label: A
# Time: 850.10 seconds - Label: N
# Time: 850.94 seconds - Label: N
# Time: 851.78 seconds - Label: N
# Time: 852.62 seconds - Label: N
# Time: 853.43 seconds - Label: N
# Time: 854.21 seconds - Label: N
# Time: 854.85 seconds - Label: A
# Time: 855.73 seconds - Label: N
# Time: 856.52 seconds - Label: N
# Time: 857.29 seconds - Label: N
# Time: 858.09 seconds - Label: N
# Time: 858.93 seconds - Label: N
# Time: 859.76 seconds - Label: N
# Time: 860.50 seconds - Label: N
# Time: 861.26 seconds - Label: N
# Time: 862.03 seconds - Label: N
# Time: 862.85 seconds - Label: N
# Time: 863.65 seconds - Label: N
# Time: 864.44 seconds - Label: N
# Time: 865.24 seconds - Label: N
# Time: 866.06 seconds - Label: N
# Time: 866.84 seconds - Label: N
# Time: 867.58 seconds - Label: N
# Time: 868.35 seconds - Label: N
# Time: 868.96 seconds - Label: A
# Time: 869.98 seconds - Label: N
# Time: 870.86 seconds - Label: N
# Time: 871.69 seconds - Label: N
# Time: 872.47 seconds - Label: N
# Time: 873.26 seconds - Label: N
# Time: 874.07 seconds - Label: N
# Time: 874.87 seconds - Label: N
# Time: 875.68 seconds - Label: N
# Time: 876.50 seconds - Label: N
# Time: 877.34 seconds - Label: N
# Time: 878.16 seconds - Label: N
# Time: 878.93 seconds - Label: N
# Time: 879.70 seconds - Label: N
# Time: 880.50 seconds - Label: N
# Time: 881.29 seconds - Label: N
# Time: 882.11 seconds - Label: N
# Time: 882.74 seconds - Label: A
# Time: 883.74 seconds - Label: N
# Time: 884.55 seconds - Label: N
# Time: 885.36 seconds - Label: N
# Time: 886.14 seconds - Label: N
# Time: 886.73 seconds - Label: A
# Time: 887.74 seconds - Label: N
# Time: 888.62 seconds - Label: N
# Time: 889.46 seconds - Label: N
# Time: 890.26 seconds - Label: N
# Time: 891.07 seconds - Label: N
# Time: 891.87 seconds - Label: N
# Time: 892.70 seconds - Label: N
# Time: 893.51 seconds - Label: N
# Time: 894.36 seconds - Label: N
# Time: 895.21 seconds - Label: N
# Time: 896.04 seconds - Label: N
# Time: 896.82 seconds - Label: N
# Time: 897.61 seconds - Label: N
# Time: 898.40 seconds - Label: N
# Time: 899.25 seconds - Label: N
# Time: 900.12 seconds - Label: N
# Time: 900.94 seconds - Label: N
# Time: 901.78 seconds - Label: N
# Time: 902.58 seconds - Label: N
# Time: 903.38 seconds - Label: N
# Time: 904.15 seconds - Label: N
# Time: 904.95 seconds - Label: N
# Time: 905.80 seconds - Label: N
# Time: 906.65 seconds - Label: N
# Time: 907.49 seconds - Label: N
# Time: 908.29 seconds - Label: N
# Time: 909.10 seconds - Label: N
# Time: 909.91 seconds - Label: N
# Time: 910.72 seconds - Label: N
# Time: 911.52 seconds - Label: N
# Time: 912.37 seconds - Label: N
# Time: 913.20 seconds - Label: N
# Time: 914.04 seconds - Label: N
# Time: 914.83 seconds - Label: N
# Time: 915.61 seconds - Label: N
# Time: 916.42 seconds - Label: N
# Time: 917.27 seconds - Label: N
# Time: 918.12 seconds - Label: N
# Time: 918.94 seconds - Label: N
# Time: 919.79 seconds - Label: N
# Time: 920.59 seconds - Label: N
# Time: 921.40 seconds - Label: N
# Time: 922.19 seconds - Label: N
# Time: 923.00 seconds - Label: N
# Time: 923.86 seconds - Label: N
# Time: 924.71 seconds - Label: N
# Time: 925.55 seconds - Label: N
# Time: 926.33 seconds - Label: N
# Time: 927.13 seconds - Label: N
# Time: 927.93 seconds - Label: N
# Time: 928.74 seconds - Label: N
# Time: 929.56 seconds - Label: N
# Time: 930.40 seconds - Label: N
# Time: 931.24 seconds - Label: N
# Time: 932.06 seconds - Label: N
# Time: 932.84 seconds - Label: N
# Time: 933.61 seconds - Label: N
# Time: 934.40 seconds - Label: N
# Time: 935.22 seconds - Label: N
# Time: 936.05 seconds - Label: N
# Time: 936.89 seconds - Label: N
# Time: 937.70 seconds - Label: N
# Time: 938.51 seconds - Label: N
# Time: 939.29 seconds - Label: N
# Time: 940.09 seconds - Label: N
# Time: 940.89 seconds - Label: N
# Time: 941.74 seconds - Label: N
# Time: 942.58 seconds - Label: N
# Time: 943.43 seconds - Label: N
# Time: 944.24 seconds - Label: N
# Time: 945.01 seconds - Label: N
# Time: 945.81 seconds - Label: N
# Time: 946.61 seconds - Label: N
# Time: 947.43 seconds - Label: N
# Time: 948.27 seconds - Label: N
# Time: 949.12 seconds - Label: N
# Time: 949.93 seconds - Label: N
# Time: 950.74 seconds - Label: N
# Time: 951.52 seconds - Label: N
# Time: 952.28 seconds - Label: N
# Time: 953.10 seconds - Label: N
# Time: 953.91 seconds - Label: N
# Time: 954.74 seconds - Label: N
# Time: 955.54 seconds - Label: N
# Time: 956.33 seconds - Label: N
# Time: 957.10 seconds - Label: N
# Time: 957.90 seconds - Label: N
# Time: 958.69 seconds - Label: N
# Time: 959.49 seconds - Label: N
# Time: 960.34 seconds - Label: N
# Time: 961.16 seconds - Label: N
# Time: 961.97 seconds - Label: N
# Time: 962.77 seconds - Label: N
# Time: 963.34 seconds - Label: A
# Time: 964.30 seconds - Label: N
# Time: 965.15 seconds - Label: N
# Time: 966.00 seconds - Label: N
# Time: 966.84 seconds - Label: N
# Time: 967.69 seconds - Label: N
# Time: 968.49 seconds - Label: N
# Time: 969.26 seconds - Label: N
# Time: 970.06 seconds - Label: N
# Time: 970.84 seconds - Label: N
# Time: 971.68 seconds - Label: N
# Time: 972.53 seconds - Label: N
# Time: 973.36 seconds - Label: N
# Time: 974.14 seconds - Label: N
# Time: 974.94 seconds - Label: N
# Time: 975.74 seconds - Label: N
# Time: 976.34 seconds - Label: A
# Time: 977.28 seconds - Label: N
# Time: 978.10 seconds - Label: N
# Time: 978.93 seconds - Label: N
# Time: 979.75 seconds - Label: N
# Time: 980.52 seconds - Label: N
# Time: 981.27 seconds - Label: N
# Time: 982.08 seconds - Label: N
# Time: 982.87 seconds - Label: N
# Time: 983.69 seconds - Label: N
# Time: 984.52 seconds - Label: N
# Time: 985.33 seconds - Label: N
# Time: 986.15 seconds - Label: N
# Time: 986.95 seconds - Label: N
# Time: 987.72 seconds - Label: N
# Time: 988.49 seconds - Label: N
# Time: 989.35 seconds - Label: N
# Time: 990.17 seconds - Label: N
# Time: 990.99 seconds - Label: N
# Time: 991.79 seconds - Label: N
# Time: 992.58 seconds - Label: N
# Time: 993.36 seconds - Label: N
# Time: 994.17 seconds - Label: N
# Time: 994.96 seconds - Label: N
# Time: 995.78 seconds - Label: N
# Time: 996.63 seconds - Label: N
# Time: 997.46 seconds - Label: N
# Time: 998.24 seconds - Label: N
# Time: 998.98 seconds - Label: N
# Time: 999.73 seconds - Label: N
# Time: 1000.51 seconds - Label: N
# Time: 1001.31 seconds - Label: N
# Time: 1002.12 seconds - Label: N
# Time: 1002.92 seconds - Label: N
# Time: 1003.73 seconds - Label: N
# Time: 1004.51 seconds - Label: N
# Time: 1005.26 seconds - Label: N
# Time: 1006.01 seconds - Label: N
# Time: 1006.81 seconds - Label: N
# Time: 1007.59 seconds - Label: N
# Time: 1008.41 seconds - Label: N
# Time: 1009.22 seconds - Label: N
# Time: 1010.02 seconds - Label: N
# Time: 1010.77 seconds - Label: N
# Time: 1011.55 seconds - Label: N
# Time: 1012.35 seconds - Label: N
# Time: 1013.14 seconds - Label: N
# Time: 1013.95 seconds - Label: N
# Time: 1014.81 seconds - Label: N
# Time: 1015.67 seconds - Label: N
# Time: 1016.43 seconds - Label: N
# Time: 1017.20 seconds - Label: N
# Time: 1018.01 seconds - Label: N
# Time: 1018.83 seconds - Label: N
# Time: 1019.62 seconds - Label: N
# Time: 1020.45 seconds - Label: N
# Time: 1021.32 seconds - Label: N
# Time: 1022.11 seconds - Label: N
# Time: 1022.91 seconds - Label: N
# Time: 1023.70 seconds - Label: N
# Time: 1024.51 seconds - Label: N
# Time: 1025.30 seconds - Label: N
# Time: 1026.14 seconds - Label: N
# Time: 1026.98 seconds - Label: N
# Time: 1027.81 seconds - Label: N
# Time: 1028.55 seconds - Label: N
# Time: 1029.33 seconds - Label: N
# Time: 1030.12 seconds - Label: N
# Time: 1030.92 seconds - Label: N
# Time: 1031.68 seconds - Label: N
# Time: 1032.51 seconds - Label: N
# Time: 1033.35 seconds - Label: N
# Time: 1034.16 seconds - Label: N
# Time: 1034.88 seconds - Label: N
# Time: 1035.65 seconds - Label: N
# Time: 1036.45 seconds - Label: N
# Time: 1037.30 seconds - Label: N
# Time: 1038.09 seconds - Label: N
# Time: 1038.89 seconds - Label: N
# Time: 1039.73 seconds - Label: N
# Time: 1040.54 seconds - Label: N
# Time: 1041.26 seconds - Label: N
# Time: 1042.01 seconds - Label: N
# Time: 1042.81 seconds - Label: N
# Time: 1043.65 seconds - Label: N
# Time: 1044.44 seconds - Label: N
# Time: 1045.24 seconds - Label: N
# Time: 1046.04 seconds - Label: N
# Time: 1046.84 seconds - Label: N
# Time: 1047.45 seconds - Label: A
# Time: 1048.34 seconds - Label: N
# Time: 1049.17 seconds - Label: N
# Time: 1050.01 seconds - Label: N
# Time: 1050.86 seconds - Label: N
# Time: 1051.69 seconds - Label: N
# Time: 1052.46 seconds - Label: N
# Time: 1053.22 seconds - Label: N
# Time: 1054.00 seconds - Label: N
# Time: 1054.81 seconds - Label: N
# Time: 1055.62 seconds - Label: N
# Time: 1056.42 seconds - Label: N
# Time: 1057.25 seconds - Label: N
# Time: 1058.05 seconds - Label: N
# Time: 1058.81 seconds - Label: N
# Time: 1059.59 seconds - Label: N
# Time: 1060.34 seconds - Label: N
# Time: 1061.15 seconds - Label: N
# Time: 1061.97 seconds - Label: N
# Time: 1062.80 seconds - Label: N
# Time: 1063.60 seconds - Label: N
# Time: 1064.40 seconds - Label: N
# Time: 1065.16 seconds - Label: N
# Time: 1065.95 seconds - Label: N
# Time: 1066.74 seconds - Label: N
# Time: 1067.55 seconds - Label: N
# Time: 1068.37 seconds - Label: N
# Time: 1069.21 seconds - Label: N
# Time: 1070.01 seconds - Label: N
# Time: 1070.80 seconds - Label: N
# Time: 1071.58 seconds - Label: N
# Time: 1072.36 seconds - Label: N
# Time: 1073.19 seconds - Label: N
# Time: 1074.03 seconds - Label: N
# Time: 1074.84 seconds - Label: N
# Time: 1075.67 seconds - Label: N
# Time: 1076.48 seconds - Label: N
# Time: 1077.25 seconds - Label: N
# Time: 1078.01 seconds - Label: N
# Time: 1078.81 seconds - Label: N
# Time: 1079.64 seconds - Label: N
# Time: 1080.50 seconds - Label: N
# Time: 1081.33 seconds - Label: N
# Time: 1082.12 seconds - Label: N
# Time: 1082.94 seconds - Label: N
# Time: 1083.75 seconds - Label: N
# Time: 1084.54 seconds - Label: N
# Time: 1085.36 seconds - Label: N
# Time: 1086.22 seconds - Label: N
# Time: 1087.07 seconds - Label: N
# Time: 1087.89 seconds - Label: N
# Time: 1088.68 seconds - Label: N
# Time: 1089.46 seconds - Label: N
# Time: 1090.26 seconds - Label: N
# Time: 1091.06 seconds - Label: N
# Time: 1091.88 seconds - Label: N
# Time: 1092.71 seconds - Label: N
# Time: 1093.54 seconds - Label: N
# Time: 1094.33 seconds - Label: N
# Time: 1095.12 seconds - Label: N
# Time: 1095.89 seconds - Label: N
# Time: 1096.67 seconds - Label: N
# Time: 1097.49 seconds - Label: N
# Time: 1098.34 seconds - Label: N
# Time: 1099.16 seconds - Label: N
# Time: 1099.97 seconds - Label: N
# Time: 1100.74 seconds - Label: N
# Time: 1101.54 seconds - Label: N
# Time: 1102.35 seconds - Label: N
# Time: 1103.15 seconds - Label: N
# Time: 1103.71 seconds - Label: A
# Time: 1104.73 seconds - Label: N
# Time: 1105.58 seconds - Label: N
# Time: 1106.37 seconds - Label: N
# Time: 1107.14 seconds - Label: N
# Time: 1107.92 seconds - Label: N
# Time: 1108.72 seconds - Label: N
# Time: 1109.54 seconds - Label: N
# Time: 1110.36 seconds - Label: N
# Time: 1111.17 seconds - Label: N
# Time: 1112.00 seconds - Label: N
# Time: 1112.78 seconds - Label: N
# Time: 1113.55 seconds - Label: N
# Time: 1114.34 seconds - Label: N
# Time: 1115.15 seconds - Label: N
# Time: 1115.99 seconds - Label: N
# Time: 1116.84 seconds - Label: N
# Time: 1117.67 seconds - Label: N
# Time: 1118.46 seconds - Label: N
# Time: 1119.26 seconds - Label: N
# Time: 1120.04 seconds - Label: N
# Time: 1120.86 seconds - Label: N
# Time: 1121.68 seconds - Label: N
# Time: 1122.50 seconds - Label: N
# Time: 1123.34 seconds - Label: N
# Time: 1124.16 seconds - Label: N
# Time: 1124.94 seconds - Label: N
# Time: 1125.71 seconds - Label: N
# Time: 1126.51 seconds - Label: N
# Time: 1127.32 seconds - Label: N
# Time: 1128.14 seconds - Label: N
# Time: 1128.96 seconds - Label: N
# Time: 1129.76 seconds - Label: N
# Time: 1130.57 seconds - Label: N
# Time: 1131.36 seconds - Label: N
# Time: 1132.11 seconds - Label: N
# Time: 1132.91 seconds - Label: N
# Time: 1133.75 seconds - Label: N
# Time: 1134.59 seconds - Label: N
# Time: 1135.41 seconds - Label: N
# Time: 1136.19 seconds - Label: N
# Time: 1136.98 seconds - Label: N
# Time: 1137.77 seconds - Label: N
# Time: 1138.56 seconds - Label: N
# Time: 1139.38 seconds - Label: N
# Time: 1140.21 seconds - Label: N
# Time: 1141.06 seconds - Label: N
# Time: 1141.86 seconds - Label: N
# Time: 1142.64 seconds - Label: N
# Time: 1143.42 seconds - Label: N
# Time: 1144.21 seconds - Label: N
# Time: 1145.02 seconds - Label: N
# Time: 1145.87 seconds - Label: N
# Time: 1146.71 seconds - Label: N
# Time: 1147.53 seconds - Label: N
# Time: 1148.34 seconds - Label: N
# Time: 1149.14 seconds - Label: N
# Time: 1149.91 seconds - Label: N
# Time: 1150.69 seconds - Label: N
# Time: 1151.50 seconds - Label: N
# Time: 1152.35 seconds - Label: N
# Time: 1153.17 seconds - Label: N
# Time: 1153.97 seconds - Label: N
# Time: 1154.73 seconds - Label: N
# Time: 1155.54 seconds - Label: N
# Time: 1156.32 seconds - Label: N
# Time: 1157.10 seconds - Label: N
# Time: 1157.91 seconds - Label: N
# Time: 1158.76 seconds - Label: N
# Time: 1159.57 seconds - Label: N
# Time: 1160.36 seconds - Label: N
# Time: 1161.13 seconds - Label: N
# Time: 1161.90 seconds - Label: N
# Time: 1162.71 seconds - Label: N
# Time: 1163.52 seconds - Label: N
# Time: 1164.32 seconds - Label: N
# Time: 1165.15 seconds - Label: N
# Time: 1165.96 seconds - Label: N
# Time: 1166.73 seconds - Label: N
# Time: 1167.51 seconds - Label: N
# Time: 1168.29 seconds - Label: N
# Time: 1169.09 seconds - Label: N
# Time: 1169.92 seconds - Label: N
# Time: 1170.76 seconds - Label: N
# Time: 1171.57 seconds - Label: N
# Time: 1172.21 seconds - Label: A
# Time: 1173.11 seconds - Label: N
# Time: 1173.90 seconds - Label: N
# Time: 1174.49 seconds - Label: A
# Time: 1175.46 seconds - Label: N
# Time: 1176.28 seconds - Label: N
# Time: 1177.13 seconds - Label: N
# Time: 1177.96 seconds - Label: N
# Time: 1178.72 seconds - Label: N
# Time: 1179.49 seconds - Label: N
# Time: 1180.26 seconds - Label: N
# Time: 1181.08 seconds - Label: N
# Time: 1181.92 seconds - Label: N
# Time: 1182.74 seconds - Label: N
# Time: 1183.55 seconds - Label: N
# Time: 1184.39 seconds - Label: N
# Time: 1185.17 seconds - Label: N
# ...
# Time: 1423.80 seconds - Label: N
# Time: 1424.59 seconds - Label: N
# Time: 1425.38 seconds - Label: N
# Time: 1426.18 seconds - Label: N
# Time: 1427.00 seconds - Label: N
# Time: 1427.82 seconds - Label: N
# Time: 1428.66 seconds - Label: N
# Time: 1429.52 seconds - Label: N
# Time: 1430.33 seconds - Label: N
# Time: 1431.09 seconds - Label: N
# Time: 1431.88 seconds - Label: N
# Time: 1432.67 seconds - Label: N
# Time: 1433.51 seconds - Label: N
# Time: 1434.36 seconds - Label: N
# Time: 1435.19 seconds - Label: N
# Time: 1436.03 seconds - Label: N
# Time: 1436.85 seconds - Label: N
# Time: 1437.65 seconds - Label: N
# Time: 1438.42 seconds - Label: N
# Time: 1439.24 seconds - Label: N
# Time: 1440.07 seconds - Label: N
# Time: 1440.93 seconds - Label: N
# Time: 1441.74 seconds - Label: N
# Time: 1442.52 seconds - Label: N
# Time: 1443.32 seconds - Label: N
# Time: 1444.12 seconds - Label: N
# Time: 1444.86 seconds - Label: N
# Time: 1445.73 seconds - Label: N
# Time: 1446.58 seconds - Label: N
# Time: 1447.17 seconds - Label: A
# Time: 1448.17 seconds - Label: N
# Time: 1448.96 seconds - Label: N
# Time: 1449.76 seconds - Label: N
# Time: 1450.58 seconds - Label: N
# Time: 1451.42 seconds - Label: N
# Time: 1452.26 seconds - Label: N
# Time: 1453.10 seconds - Label: N
# Time: 1453.93 seconds - Label: N
# Time: 1454.74 seconds - Label: N
# Time: 1455.55 seconds - Label: N
# Time: 1456.33 seconds - Label: N
# Time: 1457.16 seconds - Label: N
# Time: 1458.03 seconds - Label: N
# Time: 1458.88 seconds - Label: N
# Time: 1459.70 seconds - Label: N
# Time: 1460.50 seconds - Label: N
# Time: 1461.29 seconds - Label: N
# Time: 1462.10 seconds - Label: N
# Time: 1462.91 seconds - Label: N
# Time: 1463.72 seconds - Label: N
# Time: 1464.56 seconds - Label: N
# Time: 1465.41 seconds - Label: N
# Time: 1466.22 seconds - Label: N
# Time: 1466.99 seconds - Label: N
# Time: 1467.78 seconds - Label: N
# Time: 1468.58 seconds - Label: N
# Time: 1469.42 seconds - Label: N
# Time: 1470.26 seconds - Label: N
# Time: 1471.11 seconds - Label: N
# Time: 1471.94 seconds - Label: N
# Time: 1472.75 seconds - Label: N
# Time: 1473.53 seconds - Label: N
# Time: 1474.34 seconds - Label: N
# Time: 1475.16 seconds - Label: N
# Time: 1475.99 seconds - Label: N
# Time: 1476.86 seconds - Label: N
# Time: 1477.69 seconds - Label: N
# Time: 1478.49 seconds - Label: N
# Time: 1479.29 seconds - Label: N
# Time: 1480.08 seconds - Label: N
# Time: 1480.89 seconds - Label: N
# Time: 1481.71 seconds - Label: N
# Time: 1482.55 seconds - Label: N
# Time: 1483.37 seconds - Label: N
# Time: 1484.19 seconds - Label: N
# Time: 1484.98 seconds - Label: N
# Time: 1485.76 seconds - Label: N
# Time: 1486.56 seconds - Label: N
# Time: 1487.39 seconds - Label: N
# Time: 1488.24 seconds - Label: N
# Time: 1489.08 seconds - Label: N
# Time: 1489.90 seconds - Label: N
# Time: 1490.68 seconds - Label: N
# Time: 1491.47 seconds - Label: N
# Time: 1492.26 seconds - Label: N
# Time: 1493.07 seconds - Label: N
# Time: 1493.92 seconds - Label: N
# Time: 1494.76 seconds - Label: N
# Time: 1495.61 seconds - Label: N
# Time: 1496.41 seconds - Label: N
# Time: 1497.20 seconds - Label: N
# Time: 1497.99 seconds - Label: N
# Time: 1498.82 seconds - Label: N
# Time: 1499.65 seconds - Label: N
# Time: 1500.48 seconds - Label: N
# Time: 1501.31 seconds - Label: N
# Time: 1502.13 seconds - Label: N
# Time: 1502.92 seconds - Label: N
# Time: 1503.71 seconds - Label: N
# Time: 1504.49 seconds - Label: N
# Time: 1505.32 seconds - Label: N
# Time: 1506.18 seconds - Label: N
# Time: 1507.03 seconds - Label: N
# Time: 1507.85 seconds - Label: N
# Time: 1508.66 seconds - Label: N
# Time: 1509.46 seconds - Label: N
# Time: 1510.25 seconds - Label: N
# Time: 1511.06 seconds - Label: N
# Time: 1511.90 seconds - Label: N
# Time: 1512.75 seconds - Label: N
# Time: 1513.60 seconds - Label: N
# Time: 1514.39 seconds - Label: N
# Time: 1515.15 seconds - Label: N
# Time: 1515.95 seconds - Label: N
# Time: 1516.73 seconds - Label: N
# Time: 1517.52 seconds - Label: N
# Time: 1518.33 seconds - Label: N
# Time: 1518.87 seconds - Label: V
# Time: 1520.00 seconds - Label: N
# Time: 1520.78 seconds - Label: N
# Time: 1521.55 seconds - Label: N
# Time: 1522.31 seconds - Label: N
# Time: 1523.15 seconds - Label: N
# Time: 1523.98 seconds - Label: N
# Time: 1524.79 seconds - Label: N
# Time: 1525.60 seconds - Label: N
# Time: 1526.39 seconds - Label: N
# Time: 1527.18 seconds - Label: N
# Time: 1527.97 seconds - Label: N
# Time: 1528.74 seconds - Label: N
# Time: 1529.55 seconds - Label: N
# Time: 1530.42 seconds - Label: N
# Time: 1531.26 seconds - Label: N
# Time: 1532.03 seconds - Label: N
# Time: 1532.82 seconds - Label: N
# Time: 1533.60 seconds - Label: N
# Time: 1534.40 seconds - Label: N
# Time: 1535.22 seconds - Label: N
# Time: 1536.04 seconds - Label: N
# Time: 1536.89 seconds - Label: N
# Time: 1537.74 seconds - Label: N
# Time: 1538.54 seconds - Label: N
# Time: 1539.32 seconds - Label: N
# Time: 1540.11 seconds - Label: N
# Time: 1540.90 seconds - Label: N
# Time: 1541.74 seconds - Label: N
# Time: 1542.56 seconds - Label: N
# Time: 1543.37 seconds - Label: N
# Time: 1544.21 seconds - Label: N
# Time: 1545.01 seconds - Label: N
# Time: 1545.79 seconds - Label: N
# Time: 1546.57 seconds - Label: N
# Time: 1547.38 seconds - Label: N
# Time: 1548.22 seconds - Label: N
# Time: 1549.08 seconds - Label: N
# Time: 1549.89 seconds - Label: N
# Time: 1550.66 seconds - Label: N
# Time: 1551.46 seconds - Label: N
# Time: 1552.26 seconds - Label: N
# Time: 1553.06 seconds - Label: N
# Time: 1553.88 seconds - Label: N
# Time: 1554.71 seconds - Label: N
# Time: 1555.55 seconds - Label: N
# Time: 1556.38 seconds - Label: N
# Time: 1557.16 seconds - Label: N
# Time: 1557.91 seconds - Label: N
# Time: 1558.72 seconds - Label: N
# Time: 1559.54 seconds - Label: N
# Time: 1560.37 seconds - Label: N
# Time: 1561.16 seconds - Label: N
# Time: 1561.97 seconds - Label: N
# Time: 1562.75 seconds - Label: N
# Time: 1563.37 seconds - Label: A
# Time: 1564.28 seconds - Label: N
# Time: 1565.06 seconds - Label: N
# Time: 1565.92 seconds - Label: N
# Time: 1566.75 seconds - Label: N
# Time: 1567.56 seconds - Label: N
# Time: 1568.34 seconds - Label: N
# Time: 1569.12 seconds - Label: N
# Time: 1569.90 seconds - Label: N
# Time: 1570.70 seconds - Label: N
# Time: 1571.50 seconds - Label: N
# Time: 1572.34 seconds - Label: N
# Time: 1572.94 seconds - Label: A
# Time: 1573.93 seconds - Label: N
# Time: 1574.72 seconds - Label: N
# Time: 1575.51 seconds - Label: N
# Time: 1576.05 seconds - Label: A
# Time: 1577.00 seconds - Label: N
# Time: 1577.85 seconds - Label: N
# Time: 1578.68 seconds - Label: N
# Time: 1579.51 seconds - Label: N
# Time: 1580.33 seconds - Label: N
# Time: 1581.12 seconds - Label: N
# Time: 1581.89 seconds - Label: N
# Time: 1582.67 seconds - Label: N
# Time: 1583.49 seconds - Label: N
# Time: 1584.35 seconds - Label: N
# Time: 1585.19 seconds - Label: N
# Time: 1585.99 seconds - Label: N
# Time: 1586.79 seconds - Label: N
# Time: 1587.61 seconds - Label: N
# Time: 1588.42 seconds - Label: N
# Time: 1589.23 seconds - Label: N
# Time: 1590.08 seconds - Label: N
# Time: 1590.92 seconds - Label: N
# Time: 1591.78 seconds - Label: N
# Time: 1592.58 seconds - Label: N
# Time: 1593.36 seconds - Label: N
# Time: 1594.15 seconds - Label: N
# Time: 1594.98 seconds - Label: N
# Time: 1595.64 seconds - Label: A
# Time: 1596.63 seconds - Label: N
# Time: 1597.49 seconds - Label: N
# Time: 1598.30 seconds - Label: N
# Time: 1599.11 seconds - Label: N
# Time: 1599.89 seconds - Label: N
# Time: 1600.69 seconds - Label: N
# Time: 1601.53 seconds - Label: N
# Time: 1602.39 seconds - Label: N
# Time: 1603.23 seconds - Label: N
# Time: 1604.04 seconds - Label: N
# Time: 1604.84 seconds - Label: N
# Time: 1605.62 seconds - Label: N
# Time: 1606.42 seconds - Label: N
# Time: 1607.22 seconds - Label: N
# Time: 1608.06 seconds - Label: N
# Time: 1608.90 seconds - Label: N
# Time: 1609.58 seconds - Label: A
# Time: 1610.53 seconds - Label: N
# Time: 1611.32 seconds - Label: N
# Time: 1612.10 seconds - Label: N
# Time: 1612.91 seconds - Label: N
# Time: 1613.74 seconds - Label: N
# Time: 1614.57 seconds - Label: N
# Time: 1615.40 seconds - Label: N
# Time: 1616.21 seconds - Label: N
# Time: 1617.00 seconds - Label: N
# Time: 1617.76 seconds - Label: N
# Time: 1618.52 seconds - Label: N
# Time: 1619.22 seconds - Label: N
# Time: 1620.11 seconds - Label: N
# Time: 1620.94 seconds - Label: N
# Time: 1621.72 seconds - Label: N
# Time: 1622.49 seconds - Label: N
# Time: 1623.23 seconds - Label: N
# Time: 1623.99 seconds - Label: N
# Time: 1624.73 seconds - Label: N
# Time: 1625.49 seconds - Label: N
# Time: 1626.26 seconds - Label: N
# Time: 1627.03 seconds - Label: N
# Time: 1627.81 seconds - Label: N
# Time: 1628.54 seconds - Label: N
# Time: 1629.24 seconds - Label: N
# Time: 1629.92 seconds - Label: N
# Time: 1630.64 seconds - Label: N
# Time: 1631.39 seconds - Label: N
# Time: 1632.14 seconds - Label: N
# Time: 1632.90 seconds - Label: N
# Time: 1633.65 seconds - Label: N
# Time: 1634.38 seconds - Label: N
# Time: 1635.12 seconds - Label: N
# Time: 1635.85 seconds - Label: N
# Time: 1636.60 seconds - Label: N
# Time: 1637.37 seconds - Label: N
# Time: 1638.19 seconds - Label: N
# Time: 1639.00 seconds - Label: N
# Time: 1639.77 seconds - Label: N
# Time: 1640.52 seconds - Label: N
# Time: 1641.29 seconds - Label: N
# Time: 1642.06 seconds - Label: N
# Time: 1642.83 seconds - Label: N
# Time: 1643.63 seconds - Label: N
# Time: 1644.44 seconds - Label: N
# Time: 1645.24 seconds - Label: N
# Time: 1646.03 seconds - Label: N
# Time: 1646.81 seconds - Label: N
# Time: 1647.41 seconds - Label: A
# Time: 1648.30 seconds - Label: N
# Time: 1649.12 seconds - Label: N
# Time: 1649.97 seconds - Label: N
# Time: 1650.78 seconds - Label: N
# Time: 1651.56 seconds - Label: N
# Time: 1652.38 seconds - Label: N
# Time: 1653.13 seconds - Label: N
# Time: 1653.89 seconds - Label: N
# Time: 1654.69 seconds - Label: N
# Time: 1655.53 seconds - Label: N
# Time: 1656.33 seconds - Label: N
# Time: 1657.18 seconds - Label: N
# Time: 1658.00 seconds - Label: N
# Time: 1658.71 seconds - Label: N
# Time: 1659.45 seconds - Label: N
# Time: 1660.19 seconds - Label: N
# Time: 1660.90 seconds - Label: N
# Time: 1661.63 seconds - Label: N
# Time: 1662.38 seconds - Label: N
# Time: 1663.09 seconds - Label: N
# Time: 1663.80 seconds - Label: N
# Time: 1664.51 seconds - Label: N
# Time: 1665.19 seconds - Label: N
# Time: 1665.84 seconds - Label: N
# Time: 1666.53 seconds - Label: N
# Time: 1667.26 seconds - Label: N
# Time: 1668.01 seconds - Label: N
# Time: 1668.72 seconds - Label: N
# Time: 1669.47 seconds - Label: N
# Time: 1670.20 seconds - Label: N
# Time: 1670.94 seconds - Label: N
# Time: 1671.66 seconds - Label: N
# Time: 1672.40 seconds - Label: N
# Time: 1673.14 seconds - Label: N
# Time: 1673.92 seconds - Label: N
# Time: 1674.70 seconds - Label: N
# Time: 1675.50 seconds - Label: N
# Time: 1676.26 seconds - Label: N
# Time: 1677.01 seconds - Label: N
# Time: 1677.75 seconds - Label: N
# Time: 1678.55 seconds - Label: N
# Time: 1679.34 seconds - Label: N
# Time: 1680.12 seconds - Label: N
# Time: 1680.97 seconds - Label: N
# Time: 1681.83 seconds - Label: N
# Time: 1682.60 seconds - Label: N
# Time: 1683.36 seconds - Label: N
# Time: 1684.15 seconds - Label: N
# Time: 1684.96 seconds - Label: N
# Time: 1685.78 seconds - Label: N
# Time: 1686.61 seconds - Label: N
# Time: 1687.43 seconds - Label: N
# Time: 1688.24 seconds - Label: N
# Time: 1689.01 seconds - Label: N
# Time: 1689.75 seconds - Label: N
# Time: 1690.49 seconds - Label: N
# Time: 1691.26 seconds - Label: N
# Time: 1692.04 seconds - Label: N
# Time: 1692.85 seconds - Label: N
# Time: 1693.65 seconds - Label: N
# Time: 1694.41 seconds - Label: N
# Time: 1695.17 seconds - Label: N
# Time: 1695.96 seconds - Label: N
# Time: 1696.73 seconds - Label: N
# Time: 1697.52 seconds - Label: N
# Time: 1698.33 seconds - Label: N
# Time: 1699.15 seconds - Label: N
# Time: 1699.96 seconds - Label: N
# Time: 1700.73 seconds - Label: N
# Time: 1701.50 seconds - Label: N
# Time: 1702.28 seconds - Label: N
# Time: 1703.08 seconds - Label: N
# Time: 1703.89 seconds - Label: N
# Time: 1704.70 seconds - Label: N
# Time: 1705.51 seconds - Label: N
# Time: 1706.28 seconds - Label: N
# Time: 1707.05 seconds - Label: N
# Time: 1707.82 seconds - Label: N
# Time: 1708.58 seconds - Label: N
# Time: 1709.36 seconds - Label: N
# Time: 1710.21 seconds - Label: N
# Time: 1711.02 seconds - Label: N
# Time: 1711.81 seconds - Label: N
# Time: 1712.57 seconds - Label: N
# Time: 1713.34 seconds - Label: N
# Time: 1714.13 seconds - Label: N
# Time: 1714.91 seconds - Label: N
# Time: 1715.71 seconds - Label: N
# Time: 1716.53 seconds - Label: N
# Time: 1717.36 seconds - Label: N
# Time: 1718.13 seconds - Label: N
# Time: 1718.90 seconds - Label: N
# Time: 1719.67 seconds - Label: N
# Time: 1720.45 seconds - Label: N
# Time: 1721.26 seconds - Label: N
# Time: 1722.09 seconds - Label: N
# Time: 1722.91 seconds - Label: N
# Time: 1723.72 seconds - Label: N
# Time: 1724.52 seconds - Label: N
# Time: 1725.28 seconds - Label: N
# Time: 1726.05 seconds - Label: N
# Time: 1726.84 seconds - Label: N
# Time: 1727.62 seconds - Label: N
# Time: 1728.46 seconds - Label: N
# Time: 1729.28 seconds - Label: N
# Time: 1730.06 seconds - Label: N
# Time: 1730.80 seconds - Label: N
# Time: 1731.58 seconds - Label: N
# Time: 1732.33 seconds - Label: N
# Time: 1733.10 seconds - Label: N
# Time: 1733.86 seconds - Label: N
# Time: 1734.67 seconds - Label: N
# Time: 1735.46 seconds - Label: N
# Time: 1736.24 seconds - Label: N
# Time: 1736.97 seconds - Label: N
# Time: 1737.72 seconds - Label: N
# Time: 1738.48 seconds - Label: N
# Time: 1739.27 seconds - Label: N
# Time: 1740.08 seconds - Label: N
# Time: 1740.88 seconds - Label: N
# Time: 1741.67 seconds - Label: N
# Time: 1742.45 seconds - Label: N
# Time: 1743.21 seconds - Label: N
# Time: 1743.96 seconds - Label: N
# Time: 1744.73 seconds - Label: N
# Time: 1745.53 seconds - Label: N
# Time: 1746.36 seconds - Label: N
# Time: 1747.17 seconds - Label: N
# Time: 1747.70 seconds - Label: A
# Time: 1748.59 seconds - Label: N
# Time: 1749.34 seconds - Label: N
# Time: 1750.08 seconds - Label: N
# Time: 1750.80 seconds - Label: N
# Time: 1751.56 seconds - Label: N
# Time: 1752.32 seconds - Label: N
# Time: 1753.08 seconds - Label: N
# Time: 1753.83 seconds - Label: N
# Time: 1754.54 seconds - Label: N
# Time: 1755.27 seconds - Label: N
# Time: 1755.99 seconds - Label: N
# Time: 1756.71 seconds - Label: N
# Time: 1757.47 seconds - Label: N
# Time: 1758.22 seconds - Label: N
# Time: 1758.97 seconds - Label: N
# Time: 1759.72 seconds - Label: N
# Time: 1760.47 seconds - Label: N
# Time: 1761.19 seconds - Label: N
# Time: 1761.90 seconds - Label: N
# Time: 1762.62 seconds - Label: N
# Time: 1763.41 seconds - Label: N
# Time: 1764.19 seconds - Label: N
# Time: 1764.98 seconds - Label: N
# Time: 1765.79 seconds - Label: N
# Time: 1766.57 seconds - Label: N
# Time: 1767.33 seconds - Label: N
# Time: 1768.11 seconds - Label: N
# Time: 1768.92 seconds - Label: N
# Time: 1769.74 seconds - Label: N
# Time: 1770.55 seconds - Label: N
# Time: 1771.40 seconds - Label: N
# Time: 1772.21 seconds - Label: N
# Time: 1773.01 seconds - Label: N
# Time: 1773.78 seconds - Label: N
# Time: 1774.57 seconds - Label: N
# Time: 1775.39 seconds - Label: N
# Time: 1776.24 seconds - Label: N
# Time: 1777.07 seconds - Label: N
# Time: 1777.89 seconds - Label: N
# Time: 1778.69 seconds - Label: N
# Time: 1779.49 seconds - Label: N
# Time: 1780.28 seconds - Label: N
# Time: 1781.05 seconds - Label: N
# Time: 1781.89 seconds - Label: N
# Time: 1782.71 seconds - Label: N
# Time: 1783.51 seconds - Label: N
# Time: 1784.27 seconds - Label: N
# Time: 1785.04 seconds - Label: N
# Time: 1785.80 seconds - Label: N
# Time: 1786.57 seconds - Label: N
# Time: 1787.33 seconds - Label: N
# Time: 1788.11 seconds - Label: N
# Time: 1788.90 seconds - Label: N
# Time: 1789.68 seconds - Label: N
# Time: 1790.41 seconds - Label: N
# Time: 1791.13 seconds - Label: N
# Time: 1791.84 seconds - Label: N
# Time: 1792.56 seconds - Label: N
# Time: 1793.28 seconds - Label: N
# Time: 1794.06 seconds - Label: N
# Time: 1794.81 seconds - Label: N
# Time: 1795.54 seconds - Label: N
# Time: 1796.27 seconds - Label: N
# Time: 1796.99 seconds - Label: N
# Time: 1797.69 seconds - Label: N
# Time: 1798.37 seconds - Label: N
# Time: 1799.09 seconds - Label: N
# Time: 1799.82 seconds - Label: N
# Time: 1800.56 seconds - Label: N
# Time: 1801.33 seconds - Label: N
# Time: 1802.04 seconds - Label: N
# Time: 1802.72 seconds - Label: N
# Time: 1803.42 seconds - Label: N
# Time: 1804.12 seconds - Label: N
# Time: 1804.82 seconds - Label: N
# Time: 1805.53 seconds - Label: N

# %%
# Count the occurrences of each label
label_counts = Counter(annotations.symbol)

print("Label Distribution:")
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# Label Distribution:
# +: 1
# N: 2239
# A: 33
# V: 1

# %%
# Get the time and the signal
time = np.arange(0, len(record.p_signal) / record.fs, 1 / record.fs)  # Time vector for the ECG

# Plot the ECG signal (for the first channel)
plt.figure(figsize=(10, 6))
plt.plot(time, record.p_signal[:, 0], label="ECG Signal", color='blue')

# Highlight the apnea regions (where label 'A' occurs)
for i in range(len(annotations.sample)):
    if annotations.symbol[i] == 'A':  # Look for arrhythmia annotations
        # Convert sample to time
        start_time = annotations.sample[i] / annotations.fs
        end_time = start_time + 60  # Assumption: 1 minute duration for each apnea annotation
        plt.axvspan(start_time, end_time, color='red', alpha=0.3)  # Highlight apnea period

# Add labels and title
plt.title(f"ECG Signal with Arrhythmia Events for {ecg_file_base}")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Choose the first apnea event ('A')
for i in range(len(annotations.sample)):
    if annotations.symbol[i] == 'A':  # Look for the first apnea annotation
        apnea_sample = annotations.sample[i]
        break

# Define the time window around the apnea event (±5 seconds around the event)
window_start = apnea_sample - 5 * record.fs  # Start 5 seconds before the apnea
window_end = apnea_sample + 5 * record.fs    # End 5 seconds after the apnea

# Extract the ECG signal within the 10-second window
ecg_window = record.p_signal[window_start:window_end, 0]  # First channel
time_window = np.arange(0, len(ecg_window)) / record.fs  # Time vector for the window

# Plot the ECG signal for this 10-second window
plt.figure(figsize=(10, 6))
plt.plot(time_window, ecg_window, label="ECG Signal (Arrhythmia Event)", color='blue')

# Highlight the apnea event in the middle of the window
plt.axvline(x=5, color='red', linestyle='--', label='Arrhythmia Event')

# Add labels and title
plt.title(f"Arrhythmia Event (10-second window) for {ecg_file_base}")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# While the dotted red line specifies the point in time the sleep apnea becomes labeled as 'A', sleep apnea as a whole is categorized
# as sustained period of abnormal breathing, so this entire window would be used to feed the CNN.

# %%
# Define the start and end times of the apnea event (in seconds)
# We'll use a larger window to view the entire event duration
event_duration = 60  # for example, look at 30 seconds of data around the apnea event
window_start = apnea_sample - event_duration * record.fs // 2  # Start 15 seconds before
window_end = apnea_sample + event_duration * record.fs // 2    # End 15 seconds after
print(record.p_signal)


# Extract the ECG signal within the window around the apnea event
ecg_window = record.p_signal[window_start:window_end, 0]  # First ECG signal
time_window = np.arange(0, len(ecg_window)) / record.fs  # Time vector for the window


# Plot the ECG signal for this window
plt.figure(figsize=(10, 6))
plt.plot(time_window, ecg_window, label="ECG Signal (Arrhythmia Event)", color='blue')

# Highlight the entire apnea event duration with a shaded region
plt.axvspan(0, event_duration, color='red', alpha=0.3, label='Arrhythmia Event')

# Add labels and title
plt.title(f"Arrhythmia Event Duration for {ecg_file_base} (30-second window)")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [[-0.145 -0.065]
#  [-0.145 -0.065]
#  [-0.145 -0.065]
#  ...
#  [-0.675 -0.365]
#  [-0.765 -0.335]
#  [-1.28   0.   ]]

# %%
# Choose the first apnea event ('A')
for i in range(len(annotations.sample)):
    if annotations.symbol[i] == 'N':  # Look for the first apnea annotation
        normal_sample = annotations.sample[i]
        break

# Extract the ECG signal within the window around the normal event
ecg_window_normal = record.p_signal[window_start:window_end, 0]  # First ECG signal
time_window_normal = np.arange(0, len(ecg_window_normal)) / record.fs  # Time vector for the window

# Plot the ECG signal for this window
plt.figure(figsize=(10, 6))
plt.plot(time_window_normal, ecg_window_normal, label="ECG Signal (Normal Event)", color='green')

# Add labels and title
plt.title(f"Normal Breathing Event Duration for {ecg_file_base} (30-second window)")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Define the window size (in samples, e.g., 30 seconds worth of samples)
window_size = int(30 * record.fs)  # 30 seconds of data

# Extract annotation information as numpy arrays
annotation_samples = np.array(annotations.sample)
annotation_labels = np.array(annotations.symbol)

# Initialize lists to hold counts of "A" and "N" events in each window
apnea_counts = []
normal_counts = []

# Loop over the data in windows and count apnea events
start_time = 0
while start_time < len(record.p_signal):
    end_time = start_time + window_size
    # Get the annotations that fall within this window using boolean indexing
    window_annotations = annotation_samples[(annotation_samples >= start_time) & (annotation_samples < end_time)]
    window_labels = annotation_labels[(annotation_samples >= start_time) & (annotation_samples < end_time)]
    
    # Count the number of apneas ("A") and normal events ("N") in this window
    apnea_count = np.sum(window_labels == 'A')
    normal_count = np.sum(window_labels == 'N')
    
    # Append counts to the respective lists
    apnea_counts.append(apnea_count)
    normal_counts.append(normal_count)
    
    start_time = end_time  # Move to the next window

# Time axis for the windows
time_windows = np.arange(0, len(record.p_signal), window_size) / record.fs  # Convert to seconds

# Plot the class distribution over time
plt.figure(figsize=(12, 6))
plt.plot(time_windows, apnea_counts, label='Apnea Events (A)', color='red')
plt.plot(time_windows, normal_counts, label='Normal Events (N)', color='blue')
plt.xlabel('Time [s]')
plt.ylabel('Event Count')
plt.title('Class Distribution Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate the duration of each apnea event
apnea_durations = []

# Iterate over all annotations to find apnea events and calculate their duration
for i in range(1, len(annotations.sample)):
    if annotations.symbol[i] == 'A':  # If this annotation is an apnea event
        start_sample = annotations.sample[i]
        # Find the next annotation that is not an apnea
        for j in range(i+1, len(annotations.sample)):
            if annotations.symbol[j] != 'A':  # Found end of the apnea event
                end_sample = annotations.sample[j]
                break
        else:
            end_sample = len(record.p_signal)  # If no end is found, take the end of the signal
        
        apnea_duration = (end_sample - start_sample) / record.fs  # Convert samples to seconds
        apnea_durations.append(apnea_duration)

# Calculate the average duration of apnea events
average_apnea_duration = np.mean(apnea_durations)

# Plot the duration of each apnea event
plt.figure(figsize=(12, 6))
plt.hist(apnea_durations, bins=30, color='red', alpha=0.7)
plt.title('Distribution of Apnea Event Durations')
plt.xlabel('Duration [s]')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Print the average duration with minutes in parentheses
average_apnea_duration_minutes = average_apnea_duration / 60  # Convert to minutes
print(f"Average Apnea Duration: {average_apnea_duration:.2f} seconds ({average_apnea_duration_minutes:.2f} minutes)")
# Out:
# Average Apnea Duration: 0.96 seconds (0.02 minutes)

# %%
# Define the window size and overlap size
window_size = 500  # Length of the window (samples)
overlap_size = 250  # Overlap between windows (samples)

# Select a segment of the ECG signal to work with (for example, the first 30 seconds)
ecg_window = record.p_signal[:30 * record.fs, 0]  # First ECG signal for 30 seconds
time_window = np.arange(0, len(ecg_window)) / record.fs  # Time vector for the window

# Compute the raw spectrogram
f, t, Sxx = spectrogram(ecg_window, fs=record.fs, nperseg=window_size, noverlap=overlap_size)

# Plot the raw spectrogram
plt.figure(figsize=(12, 6))
plt.pcolormesh(t, f, 10 * np.log10(Sxx), shading='auto')  # Convert to dB for better visualization
plt.title('Raw Spectrogram of ECG Signal')
plt.xlabel('Time [s]')
plt.ylabel('Frequency [Hz]')
plt.colorbar(label='Power [dB]')
plt.show()

# %% [markdown]
# This is a raw spectrogram which compared to a regular one, can be harder for the model to interpret because they might be too variable or noisy, which is why we might need to continously try to process them (like applying a logarithmic transformation) to make the values more consistent and easier to work with. Processing them into non-raw spectrograms has been quite difficult and always producing empty graphs.
